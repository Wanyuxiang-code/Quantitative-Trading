# %% [markdown]
# ## Install yfinance

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (0.1.87)
# Requirement already satisfied: pandas>=0.24.0 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (0.24.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.26 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: numpy>=1.15 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (1.19.5)
# Requirement already satisfied: appdirs>=1.4.4 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2011k in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from pandas>=0.24.0->yfinance) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from pandas>=0.24.0->yfinance) (2.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from requests>=2.26->yfinance) (1.26.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from requests>=2.26->yfinance) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from requests>=2.26->yfinance) (3.6)
# Requirement already satisfied: six>=1.5 in /home/yuxiang23/miniconda3/envs/qtat/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.24.0->yfinance) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import yfinance and Pandas

# %%
import pandas as pd
import yfinance as yf

# %%
dir(yf)
# Out:
# ['Ticker',
#  'Tickers',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'download',
#  'multi',
#  'pdr_override',
#  'set_tz_cache_location',
#  'shared',
#  'ticker',
#  'tickers',
#  'utils',
#  'version']

# %% [markdown]
# ## How to Download Historical Price Data Using yfinance

# %% [markdown]
# We can download data for one ticker using the Ticker object and multiple tickers using the download method.

# %% [markdown]
# ### Download One Ticker Using yfinance

# %% [markdown]
# First, we need to create a ticker object and then use that object to get our data. Creating a ticker object is straightforward:

# %%
obj = yf.Ticker('goog')
obj
# Out:
# yfinance.Ticker object <GOOG>

# %%
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_earnings_history',
#  '_expirations',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_get_info',
#  '_get_ticker_tz',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_isin',
#  '_major_holders',
#  '_mutualfund_holders',
#  '_news',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_shares',
#  '_sustainability',
#  '_tz',
#  'actions',
#  'analysis',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'earnings_dates',
#  'earnings_history',
#  'financials',
#  'get_actions',
#  'get_analysis',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
#  'get_cashflow',
#  'get_dividends',
#  'get_earnings',
#  'get_earnings_dates',
#  'get_earnings_history',
#  'get_financials',
#  'get_info',
#  'get_institutional_holders',
#  'get_isin',
#  'get_major_holders',
#  'get_mutualfund_holders',
#  'get_news',
#  'get_recommendations',
#  'get_shares',
#  'get_splits',
#  'get_sustainability',
#  'history',
#  'info',
#  'institutional_holders',
#  'isin',
#  'major_holders',
#  'mutualfund_holders',
#  'news',
#  'option_chain',
#  'options',
#  'quarterly_balance_sheet',
#  'quarterly_balancesheet',
#  'quarterly_cashflow',
#  'quarterly_earnings',
#  'quarterly_financials',
#  'recommendations',
#  'session',
#  'shares',
#  'splits',
#  'stats',
#  'sustainability',
#  'ticker']

# %%
goog = yf.Ticker('goog')
data = goog.history()
data.head()
# Out:
# - GOOG: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
data = goog.history(interval='1m', start='2024-03-03', end='2024-03-10')
data.head()
# Out:
# Failed to get ticker 'GOOG' reason: [Errno Expecting value] <!DOCTYPE html>
# <html lang="zh">
# <head>
#     <meta charset="utf-8">
#     <title>Yahoo</title>
#     <meta name="viewport" content="width=device-width,initial-scale=1,minimal-ui">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <style>
# html {
#   height: 100%;
# }
# body {
#   background: #fafafc url(https://s.yimg.com/nn/img/sad-panda-201402200631.png) 50% 50%;
#   background-size: cover;
#   height: 100%;
#   text-align: center;
#   font: 300 16px "helvetica neue", helvetica, verdana, tahoma, arial, sans-serif;
# }
# #message {
#   text-align: left;
#   font-weight: 400;
#   color: #1A1A1A;
# }
# #message a {
#   padding: 0 3px;
# }
# #container {
#   position: absolute;
#   top: 50%;
#   left: 50%;
#   padding: 0 30px;
#   margin-right: -50%;
#   transform: translate(-50%, -50%);
#   max-width: 40em;
#   _width: 40em;
# }
# #container img {
#   width: 174px;
#   height: auto;
# }
# #switcher a {
#   font-weight: 400;
# }
# #switcher a.active {
#   color: #000;
#   text-decoration: none;
#   cursor: default;
# }
#     </style>
# </head>
# <body>
#   <div id="container">
#     <img src="https://s.yimg.com/rz/p/yahoo_homepage_en-US_s_f_p_bestfit_homepage_2x.png" alt="Yahoo Logo">
#     <div id="switcher">
#       <a data-lang="en" class="active" href='#'>English</a> |
#       <a data-lang="zh-Hant" href='#'>ç¹é«ä¸­æ</a> |
#       <a data-lang="zh-Hans" href='#'>ç®ä½ä¸­æ</a>
#     </div>
#     <div id="message">
#       <p>As of November 1st, 2021 Yahooâs suite of services will no longer be accessible from mainland China. Yahoo products and services remain unaffected in all other global locations. We thank you for your support and readership.</p>
#     </div>
#   </div>
# <script>
# const Msg = {
#   'en': '<p>As of November 1st, 2021 Yahooâs suite of services will no longer be accessible from mainland China. Yahoo products and services remain unaffected in all other global locations. We thank you for your support and readership.</p>',
#   'zh-Hant': '<p>2021 å¹´ 11 æ 1 æ¥èµ·ï¼ç¨æ¶å°ç¡æ³å¾ä¸­åå¤§é¸ä½¿ç¨ Yahoo çç¢åèæåãéä¸¦ä¸å½±é¿ Yahoo å¨å¨çå¶ä»å°æ¹çç¢ååæåãæåæè¬æ¨ä¸ç´ä»¥ä¾çæ¯æã</p>',
#   'zh-Hans': '<p>2021 å¹´ 11 æ 1 æ¥èµ·ï¼ç¨æ·å°æ æ³ä»ä¸­å½å¤§éä½¿ç¨ Yahoo çäº§åä¸æå¡ãè¿å¹¶ä¸å½±å Yahoo å¨å¨çå¶ä»å°æ¹çäº§ååæå¡ãæä»¬æè°¢ä½ ä¸ç´ä»¥ä¾çæ¯æã</p>'
# };
#
# const message = document.querySelector('#message');
#
# const switchLang = function (lang) {
#   message.innerHTML = Msg[lang] ? Msg[lang] : Msg.en;
#   const oldE = document.querySelector('#switcher .active');
#   const newE = document.querySelector(`#switcher a[data-lang=${lang}]`);
#   oldE.className = '';
#   newE.className = 'active';
# }
#
# const detectLang = function() {
#   const langs = window.navigator.languages ? window.navigator.languages : [window.navigator.language];
#   const availableLangs = langs.map(l => l.toLowerCase()).filter(l => /^en/.test(l) || /^zh/.test(l));
#   const selectedLang = availableLangs.length ? availableLangs[0] : 'en';
#   const prefLang =  /^en/.test(selectedLang) ? 'en' :
#       (selectedLang === 'zh-tw' || selectedLang === 'zh-hk') ? 'zh-Hant' : 'zh-Hans';
#   switchLang(prefLang);
# }
#
# const switcher = document.querySelector('#switcher');
# switcher.addEventListener('click', (e) => {
#   const lang = e.target.getAttribute('data-lang');
#   if (lang) {
#     switchLang(lang);
#   }
# });
#
# detectLang();
#
# </script>
# </body></html>
# : 0
# - GOOG: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ### Download Multiple Tickers Using yfinance

# %%
data = yf.download(['GOOG','META'], period='1mo')
data.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# - META: No data found for this date range, symbol may be delisted
# - GOOG: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [(Adj Close, GOOG), (Adj Close, META), (Close, GOOG), (Close, META), (High, GOOG), (High, META), (Low, GOOG), (Low, META), (Open, GOOG), (Open, META), (Volume, GOOG), (Volume, META)]
# Index: []

# %%
data = yf.download(['GOOG','META'], start='2021-12-10', end='2021-12-30', group_by='ticker')
data.head()
# Out:
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# - META: No data found for this date range, symbol may be delisted
# - GOOG: No data found for this date range, symbol may be delisted
# Empty DataFrame
# Columns: [(META, Open), (META, High), (META, Low), (META, Close), (META, Adj Close), (META, Volume), (GOOG, Open), (GOOG, High), (GOOG, Low), (GOOG, Close), (GOOG, Adj Close), (GOOG, Volume)]
# Index: []

# %% [markdown]
# ## How to Download Fundamental Data Using yfinance

# %% [markdown]
# We can loop through multiple tickers objects to download fundamental data for various tickers.

# %%
dhr = yf.Ticker('DHR')
info = dhr.info
info.keys()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-f7b9dbb492bf> in <module>
#       1 dhr = yf.Ticker('DHR')
# ----> 2 info = dhr.info
#       3 info.keys()
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/ticker.py in info(self)
#     145     @property
#     146     def info(self):
# --> 147         return self.get_info()
#     148
#     149     @property
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     740
#     741     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 742         self._get_info(proxy)
#     743         data = self._info
#     744         if as_dict:
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/base.py in _get_info(self, proxy)
#     530             url += "&period2={}".format(int((_datetime.datetime.now()+_datetime.timedelta(days=1)).timestamp()))
#     531             json_str = session.get(url=url, proxies=proxy, headers=utils.user_agent_headers).text
# --> 532             json_data = _json.loads(json_str)
#     533             key_stats = json_data["timeseries"]["result"][0]
#     534             if k not in key_stats:
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
info['sector']
# Out:
# 'Healthcare'

# %%
#dhr.get_earnings_dates()
dhr.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-01-28 06:00:00-05:00           NaN           NaN          NaN
# 2024-10-22 06:00:00-04:00           NaN           NaN          NaN
# 2024-07-23 08:00:00-04:00           NaN           NaN          NaN
# 2024-04-23 08:00:00-04:00          1.71           NaN          NaN
# 2024-01-30 06:00:00-05:00          1.91          2.09       0.0961
# 2023-10-24 06:00:00-04:00          1.87          2.02       0.0828
# 2023-07-25 06:00:00-04:00          2.01          2.05       0.0219
# 2023-04-25 06:00:00-04:00          2.25          2.36       0.0489
# 2023-01-24 06:00:00-05:00          2.54          2.87       0.1278
# 2022-10-20 06:00:00-04:00          2.26          2.56       0.1325
# 2022-07-21 06:00:00-04:00          2.35          2.76       0.1747
# 2022-04-21 06:00:00-04:00          2.66          2.76       0.0367

# %%
dhr.get_financials()
# Out:
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                               -42217000.0
# TaxRateForCalcs                                             0.163
# NormalizedEBITDA                                     7755000000.0
# TotalUnusualItems                                    -259000000.0
# TotalUnusualItemsExcludingGoodwill                   -259000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   4221000000.0
# ReconciledDepreciation                               2166000000.0
# ReconciledCostOfRevenue                              9856000000.0
# EBITDA                                               7496000000.0
# EBIT                                                 5330000000.0
# NetInterestIncome                                      17000000.0
# InterestExpense                                       286000000.0
# InterestIncome                                        303000000.0
# NormalizedIncome                                     4437783000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      4764000000.0
# TotalExpenses                                       18611000000.0
# TotalOperatingIncomeAsReported                       5202000000.0
# DilutedAverageShares                                  743100000.0
# BasicAverageShares                                    736500000.0
# DilutedEPS                                                   6.38
# BasicEPS                                                     6.44
# DilutedNIAvailtoComStockholders                      4743000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          4743000000.0
# PreferredStockDividends                                21000000.0
# NetIncome                                            4764000000.0
# NetIncomeIncludingNoncontrollingInterests            4764000000.0
# NetIncomeDiscontinuousOperations                      543000000.0
# NetIncomeContinuousOperations                        4221000000.0
# TaxProvision                                          823000000.0
# PretaxIncome                                         5044000000.0
# OtherIncomeExpense                                   -252000000.0
# OtherNonOperatingIncomeExpenses                         7000000.0
# SpecialIncomeCharges                                 -108000000.0
# GainOnSaleOfBusiness                                          0.0
# OtherSpecialCharges                                           NaN
# WriteOff                                              108000000.0
# GainOnSaleOfSecurity                                 -151000000.0
# NetNonOperatingInterestIncomeExpense                   17000000.0
# InterestExpenseNonOperating                           286000000.0
# InterestIncomeNonOperating                            303000000.0
# OperatingIncome                                      5279000000.0
# OperatingExpense                                     8755000000.0
# OtherOperatingExpenses                                        NaN
# ResearchAndDevelopment                               1503000000.0
# SellingGeneralAndAdministration                      7252000000.0
# GrossProfit                                         14034000000.0
# CostOfRevenue                                        9856000000.0
# TotalRevenue                                        23890000000.0
# OperatingRevenue                                    23890000000.0
#
#                                                        2022-12-31  \
# TaxEffectOfUnusualItems                               -30894000.0
# TaxRateForCalcs                                             0.114
# NormalizedEBITDA                                     9753000000.0
# TotalUnusualItems                                    -271000000.0
# TotalUnusualItemsExcludingGoodwill                   -271000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   6328000000.0
# ReconciledDepreciation                               2132000000.0
# ReconciledCostOfRevenue                             10455000000.0
# EBITDA                                               9482000000.0
# EBIT                                                 7350000000.0
# NetInterestIncome                                    -163000000.0
# InterestExpense                                       204000000.0
# InterestIncome                                         41000000.0
# NormalizedIncome                                     6568106000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      7209000000.0
# TotalExpenses                                       19107000000.0
# TotalOperatingIncomeAsReported                       7536000000.0
# DilutedAverageShares                                  737100000.0
# BasicAverageShares                                    725100000.0
# DilutedEPS                                                   9.66
# BasicEPS                                                      9.8
# DilutedNIAvailtoComStockholders                      7103000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          7103000000.0
# PreferredStockDividends                               106000000.0
# NetIncome                                            7209000000.0
# NetIncomeIncludingNoncontrollingInterests            7209000000.0
# NetIncomeDiscontinuousOperations                      881000000.0
# NetIncomeContinuousOperations                        6328000000.0
# TaxProvision                                          818000000.0
# PretaxIncome                                         7146000000.0
# OtherIncomeExpense                                   -227000000.0
# OtherNonOperatingIncomeExpenses                        44000000.0
# SpecialIncomeCharges                                  -91000000.0
# GainOnSaleOfBusiness                                          0.0
# OtherSpecialCharges                                           NaN
# WriteOff                                               91000000.0
# GainOnSaleOfSecurity                                 -180000000.0
# NetNonOperatingInterestIncomeExpense                 -163000000.0
# InterestExpenseNonOperating                           204000000.0
# InterestIncomeNonOperating                             41000000.0
# OperatingIncome                                      7536000000.0
# OperatingExpense                                     8652000000.0
# OtherOperatingExpenses                                        NaN
# ResearchAndDevelopment                               1528000000.0
# SellingGeneralAndAdministration                      7124000000.0
# GrossProfit                                         16188000000.0
# CostOfRevenue                                       10455000000.0
# TotalRevenue                                        26643000000.0
# OperatingRevenue                                    26643000000.0
#
#                                                        2021-12-31  \
# TaxEffectOfUnusualItems                                48900000.0
# TaxRateForCalcs                                             0.163
# NormalizedEBITDA                                     8504000000.0
# TotalUnusualItems                                     300000000.0
# TotalUnusualItemsExcludingGoodwill                    300000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   5447000000.0
# ReconciledDepreciation                               2062000000.0
# ReconciledCostOfRevenue                              9563000000.0
# EBITDA                                               8804000000.0
# EBIT                                                 6742000000.0
# NetInterestIncome                                    -220000000.0
# InterestExpense                                       231000000.0
# InterestIncome                                         11000000.0
# NormalizedIncome                                     5195900000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      6433000000.0
# TotalExpenses                                       18415000000.0
# TotalOperatingIncomeAsReported                       6377000000.0
# DilutedAverageShares                                  736800000.0
# BasicAverageShares                                    714600000.0
# DilutedEPS                                                   8.61
# BasicEPS                                                     8.77
# DilutedNIAvailtoComStockholders                      6269000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          6269000000.0
# PreferredStockDividends                               164000000.0
# NetIncome                                            6433000000.0
# NetIncomeIncludingNoncontrollingInterests            6433000000.0
# NetIncomeDiscontinuousOperations                      986000000.0
# NetIncomeContinuousOperations                        5447000000.0
# TaxProvision                                         1064000000.0
# PretaxIncome                                         6511000000.0
# OtherIncomeExpense                                    344000000.0
# OtherNonOperatingIncomeExpenses                        44000000.0
# SpecialIncomeCharges                                 -101000000.0
# GainOnSaleOfBusiness                                    5000000.0
# OtherSpecialCharges                                    96000000.0
# WriteOff                                               10000000.0
# GainOnSaleOfSecurity                                  401000000.0
# NetNonOperatingInterestIncomeExpense                 -220000000.0
# InterestExpenseNonOperating                           231000000.0
# InterestIncomeNonOperating                             11000000.0
# OperatingIncome                                      6387000000.0
# OperatingExpense                                     8852000000.0
# OtherOperatingExpenses                                547000000.0
# ResearchAndDevelopment                               1498000000.0
# SellingGeneralAndAdministration                      6807000000.0
# GrossProfit                                         15239000000.0
# CostOfRevenue                                        9563000000.0
# TotalRevenue                                        24802000000.0
# OperatingRevenue                                    24802000000.0
#
#                                                        2020-12-31
# TaxEffectOfUnusualItems                                84483000.0
# TaxRateForCalcs                                             0.189
# NormalizedEBITDA                                     6098000000.0
# TotalUnusualItems                                     447000000.0
# TotalUnusualItemsExcludingGoodwill                    447000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   3646000000.0
# ReconciledDepreciation                               1775000000.0
# ReconciledCostOfRevenue                              9809000000.0
# EBITDA                                               6545000000.0
# EBIT                                                 4770000000.0
# NetInterestIncome                                    -204000000.0
# InterestExpense                                       275000000.0
# InterestIncome                                         71000000.0
# NormalizedIncome                                     3283483000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      3646000000.0
# TotalExpenses                                       18053000000.0
# TotalOperatingIncomeAsReported                       4231000000.0
# DilutedAverageShares                                  718700000.0
# BasicAverageShares                                    706200000.0
# DilutedEPS                                                   4.89
# BasicEPS                                                     4.97
# DilutedNIAvailtoComStockholders                      3510000000.0
# AverageDilutionEarnings                                 1000000.0
# NetIncomeCommonStockholders                          3510000000.0
# PreferredStockDividends                               136000000.0
# NetIncome                                            3646000000.0
# NetIncomeIncludingNoncontrollingInterests            3646000000.0
# NetIncomeDiscontinuousOperations                              0.0
# NetIncomeContinuousOperations                        3646000000.0
# TaxProvision                                          849000000.0
# PretaxIncome                                         4495000000.0
# OtherIncomeExpense                                    468000000.0
# OtherNonOperatingIncomeExpenses                        21000000.0
# SpecialIncomeCharges                                  429000000.0
# GainOnSaleOfBusiness                                  455000000.0
# OtherSpecialCharges                                    26000000.0
# WriteOff                                                      NaN
# GainOnSaleOfSecurity                                   18000000.0
# NetNonOperatingInterestIncomeExpense                 -204000000.0
# InterestExpenseNonOperating                           275000000.0
# InterestIncomeNonOperating                             71000000.0
# OperatingIncome                                      4231000000.0
# OperatingExpense                                     8244000000.0
# OtherOperatingExpenses                                        NaN
# ResearchAndDevelopment                               1348000000.0
# SellingGeneralAndAdministration                      6896000000.0
# GrossProfit                                         12475000000.0
# CostOfRevenue                                        9809000000.0
# TotalRevenue                                        22284000000.0
# OperatingRevenue                                    22284000000.0

# %%
pnl = dhr.financials
bs = dhr.balancesheet
cf = dhr.cashflow
fs = pd.concat([pnl,bs,cf])
fs.to_csv('data/dhr_fs.csv')

# %%
fs.T
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2023-12-31                 -42217000.0              0.163      7755000000.0
# 2022-12-31                 -30894000.0              0.114      9753000000.0
# 2021-12-31                  48900000.0              0.163      8504000000.0
# 2020-12-31                  84483000.0              0.189      6098000000.0
#
#            Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 2023-12-31        -259000000.0                           -259000000.0
# 2022-12-31        -271000000.0                           -271000000.0
# 2021-12-31         300000000.0                            300000000.0
# 2020-12-31         447000000.0                            447000000.0
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2023-12-31                                       4221000000.0
# 2022-12-31                                       6328000000.0
# 2021-12-31                                       5447000000.0
# 2020-12-31                                       3646000000.0
#
#            Reconciled Depreciation Reconciled Cost Of Revenue        EBITDA  \
# 2023-12-31            2166000000.0               9856000000.0  7496000000.0
# 2022-12-31            2132000000.0              10455000000.0  9482000000.0
# 2021-12-31            2062000000.0               9563000000.0  8804000000.0
# 2020-12-31            1775000000.0               9809000000.0  6545000000.0
#
#                     EBIT  ... Other Non Cash Items Stock Based Compensation  \
# 2023-12-31  5330000000.0  ...            8000000.0              306000000.0
# 2022-12-31  7350000000.0  ...                  NaN              295000000.0
# 2021-12-31  6742000000.0  ...          601000000.0              184000000.0
# 2020-12-31  4770000000.0  ...          457000000.0              187000000.0
#
#            Depreciation Amortization Depletion Depreciation And Amortization  \
# 2023-12-31                        2166000000.0                  2166000000.0
# 2022-12-31                        2132000000.0                  2132000000.0
# 2021-12-31                        2062000000.0                  2062000000.0
# 2020-12-31                        1775000000.0                  1775000000.0
#
#            Amortization Cash Flow Amortization Of Intangibles Depreciation  \
# 2023-12-31           1491000000.0                1491000000.0  675000000.0
# 2022-12-31           1434000000.0                1434000000.0  698000000.0
# 2021-12-31           1388000000.0                1388000000.0  674000000.0
# 2020-12-31           1138000000.0                1138000000.0  637000000.0
#
#            Operating Gains Losses Gain Loss On Sale Of Business  \
# 2023-12-31            182000000.0                   182000000.0
# 2022-12-31            271000000.0                   271000000.0
# 2021-12-31           -310000000.0                  -406000000.0
# 2020-12-31           -429000000.0                  -455000000.0
#
#            Net Income From Continuing Operations
# 2023-12-31                          4221000000.0
# 2022-12-31                          6328000000.0
# 2021-12-31                          5447000000.0
# 2020-12-31                          3646000000.0
#
# [4 rows x 190 columns]

# %% [markdown]
# ### Download Fundamentals for Multiple Tickers Using yfinance

# %%
tickers = ['FB','AMZN','NFLX','GOOG']
tickers
# Out:
# ['FB', 'AMZN', 'NFLX', 'GOOG']

# %%
tickers = [yf.Ticker(ticker) for ticker in tickers]
tickers
# Out:
# [yfinance.Ticker object <FB>,
#  yfinance.Ticker object <AMZN>,
#  yfinance.Ticker object <NFLX>,
#  yfinance.Ticker object <GOOG>]

# %%
dfs = [] # list for each ticker's dataframe
for ticker in tickers:
    # get each financial statement
    pnl = ticker.financials
    bs = ticker.balancesheet
    cf = ticker.cashflow
    
    # concatenate into one dataframe
    fs = pd.concat([pnl, bs, cf])
    
    # make dataframe format nicer
    data = fs.T # Swap dates and columns
    data = data.reset_index() # reset index (date) into a column
    data.columns = ['Date', *data.columns[1:]] # Rename old index from '' to Date
    data['Ticker'] = ticker.ticker # Add ticker to dataframe
    dfs.append(data)
data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-21-8431f2bbe176> in <module>
#       2 for ticker in tickers:
#       3     # get each financial statement
# ----> 4     pnl = ticker.financials
#       5     bs = ticker.balancesheet
#       6     cf = ticker.cashflow
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/ticker.py in financials(self)
#     165     @property
#     166     def financials(self):
# --> 167         return self.get_financials()
#     168
#     169     @property
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/base.py in get_financials(self, proxy, as_dict, freq)
#     770
#     771     def get_financials(self, proxy=None, as_dict=False, freq="yearly"):
# --> 772         self._get_fundamentals(proxy=proxy)
#     773         data = self._financials[freq]
#     774         if as_dict:
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/base.py in _get_fundamentals(self, proxy)
#     610                     '% Out'].str.replace('%', '').astype(float) / 100
#     611
# --> 612         self._get_info(proxy)
#     613
#     614         # get fundamentals
#
# ~/miniconda3/envs/qtat/lib/python3.6/site-packages/yfinance/base.py in _get_info(self, proxy)
#     530             url += "&period2={}".format(int((_datetime.datetime.now()+_datetime.timedelta(days=1)).timestamp()))
#     531             json_str = session.get(url=url, proxies=proxy, headers=utils.user_agent_headers).text
# --> 532             json_data = _json.loads(json_str)
#     533             key_stats = json_data["timeseries"]["result"][0]
#     534             if k not in key_stats:
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/miniconda3/envs/qtat/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data.iloc[:,:3]
# Out:
#         Date Tax Effect Of Unusual Items Tax Rate For Calcs
# 0 2023-12-31                -286479000.0              0.139
# 1 2022-12-31                -981507000.0              0.159
# 2 2021-12-31                1948860000.0              0.162
# 3 2020-12-31            970572126.783412           0.162493

# %%
df = pd.concat(dfs, ignore_index=True)
df = df.set_index(['Ticker','Date'])
df
# Out:
#                   Tax Effect Of Unusual Items Tax Rate For Calcs  \
# Ticker Date
# AMZN   2023-12-31            211380035.679101           0.189579
#        2022-12-31               -3415860000.0               0.21
#        2021-12-31           1839997169.143666            0.12558
#        2020-12-31            287626230.457441           0.118413
# NFLX   2023-12-31                         0.0               0.13
#        2022-12-31                         0.0               0.15
#        2021-12-31                         0.0               0.12
#        2020-12-31                         0.0               0.14
# GOOG   2023-12-31                -286479000.0              0.139
#        2022-12-31                -981507000.0              0.159
#        2021-12-31                1948860000.0              0.162
#        2020-12-31            970572126.783412           0.162493
#
#                   Normalized EBITDA Total Unusual Items  \
# Ticker Date
# AMZN   2023-12-31     88287000000.0        1115000000.0
#        2022-12-31     54618000000.0      -16266000000.0
#        2021-12-31     59741000000.0       14652000000.0
#        2020-12-31     48647000000.0        2429000000.0
# NFLX   2023-12-31     21508387000.0                 NaN
#        2022-12-31     20332955000.0                 NaN
#        2021-12-31     19044502000.0                 NaN
#        2020-12-31     15507911000.0                 NaN
# GOOG   2023-12-31    100032000000.0       -2061000000.0
#        2022-12-31     91333000000.0       -6173000000.0
#        2021-12-31     91491000000.0       12030000000.0
#        2020-12-31     55941000000.0        5973000000.0
#
#                   Total Unusual Items Excluding Goodwill  \
# Ticker Date
# AMZN   2023-12-31                           1115000000.0
#        2022-12-31                         -16266000000.0
#        2021-12-31                          14652000000.0
#        2020-12-31                           2429000000.0
# NFLX   2023-12-31                                    NaN
#        2022-12-31                                    NaN
#        2021-12-31                                    NaN
#        2020-12-31                                    NaN
# GOOG   2023-12-31                          -2061000000.0
#        2022-12-31                          -6173000000.0
#        2021-12-31                          12030000000.0
#        2020-12-31                           5973000000.0
#
#                   Net Income From Continuing Operation Net Minority Interest  \
# Ticker Date
# AMZN   2023-12-31                                      30425000000.0
#        2022-12-31                                      -2722000000.0
#        2021-12-31                                      33364000000.0
#        2020-12-31                                      21331000000.0
# NFLX   2023-12-31                                       5407990000.0
#        2022-12-31                                       4491924000.0
#        2021-12-31                                       5116228000.0
#        2020-12-31                                       2761395000.0
# GOOG   2023-12-31                                      73795000000.0
#        2022-12-31                                      59972000000.0
#        2021-12-31                                      76033000000.0
#        2020-12-31                                      40269000000.0
#
#                   Reconciled Depreciation Reconciled Cost Of Revenue  \
# Ticker Date
# AMZN   2023-12-31           48663000000.0             480980000000.0
#        2022-12-31           41921000000.0             446343000000.0
#        2021-12-31           34433000000.0             403507000000.0
#        2020-12-31           25251000000.0             334564000000.0
# NFLX   2023-12-31           14554384000.0              19715368000.0
#        2022-12-31           14362814000.0              19168285000.0
#        2021-12-31           12438779000.0              17332683000.0
#        2020-12-31           10922622000.0              15276319000.0
# GOOG   2023-12-31           11946000000.0             133332000000.0
#        2022-12-31           13475000000.0             126203000000.0
#        2021-12-31           12441000000.0             110939000000.0
#        2020-12-31           13697000000.0              84732000000.0
#
#                            EBITDA           EBIT  ... Other Payable  \
# Ticker Date                                       ...
# AMZN   2023-12-31   89402000000.0  40739000000.0  ...           NaN
#        2022-12-31   38352000000.0  -3569000000.0  ...           NaN
#        2021-12-31   74393000000.0  39960000000.0  ...           NaN
#        2020-12-31   51076000000.0  25825000000.0  ...           NaN
# NFLX   2023-12-31   21508387000.0   6954003000.0  ...           NaN
#        2022-12-31   20332955000.0   5970141000.0  ...           NaN
#        2021-12-31   19044502000.0   6605723000.0  ...           NaN
#        2020-12-31   15507911000.0   4585289000.0  ...           NaN
# GOOG   2023-12-31   97971000000.0  86025000000.0  ...           NaN
#        2022-12-31   85160000000.0  71685000000.0  ...           NaN
#        2021-12-31  103521000000.0  91080000000.0  ...   397000000.0
#        2020-12-31   61914000000.0  48217000000.0  ...   754000000.0
#
#                   Total Tax Payable Income Tax Payable  \
# Ticker Date
# AMZN   2023-12-31               NaN                NaN
#        2022-12-31               NaN                NaN
#        2021-12-31               NaN                NaN
#        2020-12-31               NaN                NaN
# NFLX   2023-12-31               NaN                NaN
#        2022-12-31               NaN                NaN
#        2021-12-31               NaN                NaN
#        2020-12-31               NaN                NaN
# GOOG   2023-12-31      2748000000.0       2748000000.0
#        2022-12-31      1632000000.0       1632000000.0
#        2021-12-31       808000000.0        808000000.0
#        2020-12-31      1485000000.0       1485000000.0
#
#                   Non Current Deferred Assets  \
# Ticker Date
# AMZN   2023-12-31                         NaN
#        2022-12-31                         NaN
#        2021-12-31                         NaN
#        2020-12-31                         NaN
# NFLX   2023-12-31                         NaN
#        2022-12-31                         NaN
#        2021-12-31                         NaN
#        2020-12-31                         NaN
# GOOG   2023-12-31               12169000000.0
#        2022-12-31                5261000000.0
#        2021-12-31                1284000000.0
#        2020-12-31                1084000000.0
#
#                   Non Current Deferred Taxes Assets Investments And Advances  \
# Ticker Date
# AMZN   2023-12-31                               NaN                      NaN
#        2022-12-31                               NaN                      NaN
#        2021-12-31                               NaN                      NaN
#        2020-12-31                               NaN                      NaN
# NFLX   2023-12-31                               NaN                      NaN
#        2022-12-31                               NaN                      NaN
#        2021-12-31                               NaN                      NaN
#        2020-12-31                               NaN                      NaN
# GOOG   2023-12-31                     12169000000.0            31008000000.0
#        2022-12-31                      5261000000.0            30492000000.0
#        2021-12-31                      1284000000.0            29549000000.0
#        2020-12-31                      1084000000.0            20703000000.0
#
#                   Investmentin Financial Assets Available For Sale Securities  \
# Ticker Date
# AMZN   2023-12-31                           NaN                           NaN
#        2022-12-31                           NaN                           NaN
#        2021-12-31                           NaN                           NaN
#        2020-12-31                           NaN                           NaN
# NFLX   2023-12-31                           NaN                           NaN
#        2022-12-31                           NaN                           NaN
#        2021-12-31                           NaN                           NaN
#        2020-12-31                           NaN                           NaN
# GOOG   2023-12-31                 31008000000.0                 31008000000.0
#        2022-12-31                 30492000000.0                 30492000000.0
#        2021-12-31                 29549000000.0                 29549000000.0
#        2020-12-31                 20703000000.0                 20703000000.0
#
#                   Proceeds From Stock Option Exercised  \
# Ticker Date
# AMZN   2023-12-31                                  NaN
#        2022-12-31                                  NaN
#        2021-12-31                                  NaN
#        2020-12-31                                  NaN
# NFLX   2023-12-31                                  NaN
#        2022-12-31                                  NaN
#        2021-12-31                                  NaN
#        2020-12-31                                  NaN
# GOOG   2023-12-31                        -9837000000.0
#        2022-12-31                        -9300000000.0
#        2021-12-31                       -10162000000.0
#        2020-12-31                        -5720000000.0
#
#                   Gain Loss On Investment Securities
# Ticker Date
# AMZN   2023-12-31                                NaN
#        2022-12-31                                NaN
#        2021-12-31                                NaN
#        2020-12-31                                NaN
# NFLX   2023-12-31                                NaN
#        2022-12-31                                NaN
#        2021-12-31                                NaN
#        2020-12-31                                NaN
# GOOG   2023-12-31                        823000000.0
#        2022-12-31                       5519000000.0
#        2021-12-31                     -12270000000.0
#        2020-12-31                      -6317000000.0
#
# [12 rows x 194 columns]

# %% [markdown]
# ## Hows to Get Options Data Using yfinance

# %% [markdown]
# Options give traders the right but not the obligation to buy or sell underlying assets at a specific price at a predetermined date. Options Trading has matured over the past century and has seen landmark events. Here is a chronicle of the history of options trading and the major events that have led to its evolution.

# %% [markdown]
# To download options data, you'll need to use the `Ticker.options` and `Ticker.option_chain` methods.

# %%
aapl = yf.Ticker('aapl')
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
options = aapl.option_chain()

# %%
calls = options.calls
calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL240315C00005000 2024-03-07 20:50:00+00:00     5.0     164.30    0.00
# 1   AAPL240315C00010000 2024-02-06 14:43:04+00:00    10.0     178.00  158.75
# 2   AAPL240315C00015000 2024-02-14 20:53:09+00:00    15.0     168.80    0.00
# 3   AAPL240315C00020000 2024-02-09 14:30:01+00:00    20.0     168.96  150.35
# 4   AAPL240315C00025000 2024-02-14 20:53:11+00:00    25.0     158.85    0.00
# ..                  ...                       ...     ...        ...     ...
# 68  AAPL240315C00280000 2024-01-22 15:25:10+00:00   280.0       0.01    0.00
# 69  AAPL240315C00285000 2024-03-11 18:14:39+00:00   285.0       0.01    0.00
# 70  AAPL240315C00290000 2024-02-14 15:07:46+00:00   290.0       0.01    0.00
# 71  AAPL240315C00300000 2024-01-08 14:30:03+00:00   300.0       0.01    0.00
# 72  AAPL240315C00310000 2024-03-12 18:09:16+00:00   310.0       0.01    0.00
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.00     0.0            0.0     105             0           0.000010
# 1   159.45     0.0            0.0       1             0           0.000010
# 2     0.00     0.0            0.0       9             0           0.000010
# 3   151.55     0.0            0.0       2             1           0.000010
# 4     0.00     0.0            0.0       5             0           0.000010
# ..     ...     ...            ...     ...           ...                ...
# 68    0.01     0.0            0.0       4          1029           1.625002
# 69    0.00     0.0            0.0       6             0           0.500005
# 70    0.00     0.0            0.0       1             0           0.500005
# 71    0.00     0.0            0.0       5          3181           0.500005
# 72    0.00     0.0            0.0      23             0           0.500005
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# ..         ...          ...      ...
# 68       False      REGULAR      USD
# 69       False      REGULAR      USD
# 70       False      REGULAR      USD
# 71       False      REGULAR      USD
# 72       False      REGULAR      USD
#
# [73 rows x 14 columns]

# %%
type(options)
# Out:
# yfinance.ticker.Options

# %%
puts = options.puts
puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL240315P00005000 2024-03-12 14:37:18+00:00     5.0       0.01    0.00
# 1   AAPL240315P00010000 2024-03-11 13:30:17+00:00    10.0       0.01    0.00
# 2   AAPL240315P00050000 2024-03-08 20:01:03+00:00    50.0       0.01    0.00
# 3   AAPL240315P00055000 2023-12-12 20:38:56+00:00    55.0       0.01    0.00
# 4   AAPL240315P00060000 2024-03-11 16:29:59+00:00    60.0       0.01    0.00
# ..                  ...                       ...     ...        ...     ...
# 61  AAPL240315P00275000 2022-12-21 17:27:28+00:00   275.0     139.65  137.80
# 62  AAPL240315P00280000 2023-05-04 19:09:28+00:00   280.0     114.02   97.05
# 63  AAPL240315P00285000 2023-02-15 15:38:45+00:00   285.0     130.86  129.35
# 64  AAPL240315P00300000 2023-12-27 18:07:26+00:00   300.0     107.05  106.70
# 65  AAPL240315P00310000 2024-01-11 19:10:30+00:00   310.0     124.85  120.80
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.00     0.0            0.0     3.0             0           0.500005
# 1     0.00     0.0            0.0     8.0             0           0.500005
# 2     0.00     0.0            0.0    37.0             0           0.500005
# 3     0.10     0.0            0.0     3.0           999           4.750004
# 4     0.00     0.0            0.0     1.0             0           0.500005
# ..     ...     ...            ...     ...           ...                ...
# 61  140.10     0.0            0.0     NaN             0          10.095707
# 62  100.65     0.0            0.0     NaN             0           0.000010
# 63  131.10     0.0            0.0     3.0             0           7.271974
# 64  108.20     0.0            0.0    50.0             0           0.000010
# 65  121.35     0.0            0.0     NaN             0           0.000010
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# ..         ...          ...      ...
# 61        True      REGULAR      USD
# 62        True      REGULAR      USD
# 63        True      REGULAR      USD
# 64        True      REGULAR      USD
# 65        True      REGULAR      USD
#
# [66 rows x 14 columns]

# %% [markdown]
# ## How to Get Institutional Holders Using yfinance

# %%
aapl.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld      Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0834  1303688506
# 1    2023-06-30                     Blackrock Inc.   0.0665  1039640859
# 2    2023-06-30            Berkshire Hathaway, Inc   0.0586   915560382
# 3    2023-06-30           State Street Corporation   0.0370   578897858
# 4    2023-06-30                           FMR, LLC   0.0196   307066638
# 5    2023-06-30      Geode Capital Management, LLC   0.0186   291538165
# 6    2023-06-30      Price (T.Rowe) Associates Inc   0.0145   226650943
# 7    2023-06-30                     Morgan Stanley   0.0131   204714950
# 8    2022-12-31  Norges Bank Investment Management   0.0107   167374278
# 9    2023-06-30         Northern Trust Corporation   0.0105   164536073
#
#           Value
# 0  252876459508
# 1  201659137420
# 2  177591247296
# 3  112288817516
# 4   59561715772
# 5   56549657865
# 6   43963483413
# 7   39708558851
# 8   21746939940
# 9   31915062079

# %% [markdown]
# ## Why You Shouldn’t Use Yahoo Finance for Live Trading

# %%
fb = yf.Ticker('fb')
meta = yf.Ticker('meta')
fb.get_cashflow()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
meta.get_cashflow()
# Out:
#                                               2023-12-31     2022-12-31  \
# FreeCashFlow                               43847000000.0  19044000000.0
# RepurchaseOfCapitalStock                  -19774000000.0 -27956000000.0
# RepaymentOfDebt                            -1058000000.0   -850000000.0
# IssuanceOfDebt                              8455000000.0   9921000000.0
# CapitalExpenditure                        -27266000000.0 -31431000000.0
# InterestPaidSupplementalData                 448000000.0            0.0
# IncomeTaxPaidSupplementalData               6607000000.0   6407000000.0
# EndCashPosition                            42827000000.0  15596000000.0
# BeginningCashPosition                      15596000000.0  16865000000.0
# EffectOfExchangeRateChanges                  113000000.0   -638000000.0
# ChangesInCash                              27118000000.0   -631000000.0
# FinancingCashFlow                         -19500000000.0 -22136000000.0
# CashFlowFromContinuingFinancingActivities -19500000000.0 -22136000000.0
# NetOtherFinancingCharges                   -7123000000.0  -3251000000.0
# NetCommonStockIssuance                    -19774000000.0 -27956000000.0
# CommonStockPayments                       -19774000000.0 -27956000000.0
# NetIssuancePaymentsOfDebt                   7397000000.0   9071000000.0
# NetShortTermDebtIssuance                             NaN            NaN
# NetLongTermDebtIssuance                     7397000000.0   9071000000.0
# LongTermDebtPayments                       -1058000000.0   -850000000.0
# LongTermDebtIssuance                        8455000000.0   9921000000.0
# InvestingCashFlow                         -24495000000.0 -28970000000.0
# CashFlowFromContinuingInvestingActivities -24495000000.0 -28970000000.0
# NetOtherInvestingChanges                     -23000000.0     -4000000.0
# NetInvestmentPurchaseAndSale                3202000000.0   3532000000.0
# SaleOfInvestment                            6184000000.0  13158000000.0
# PurchaseOfInvestment                       -2982000000.0  -9626000000.0
# NetBusinessPurchaseAndSale                  -629000000.0  -1312000000.0
# PurchaseOfBusiness                          -629000000.0  -1312000000.0
# NetPPEPurchaseAndSale                     -27045000000.0 -31186000000.0
# SaleOfPPE                                    221000000.0    245000000.0
# PurchaseOfPPE                             -27266000000.0 -31431000000.0
# OperatingCashFlow                          71113000000.0  50475000000.0
# CashFlowFromContinuingOperatingActivities  71113000000.0  50475000000.0
# ChangeInWorkingCapital                      3836000000.0   5683000000.0
# ChangeInOtherWorkingCapital                          NaN            NaN
# ChangeInOtherCurrentLiabilities              624000000.0    886000000.0
# ChangeInOtherCurrentAssets                   -80000000.0   -106000000.0
# ChangeInPayablesAndAccruedExpense           5132000000.0   4510000000.0
# ChangeInAccruedExpense                      5352000000.0   4210000000.0
# ChangeInPayable                             -220000000.0    300000000.0
# ChangeInAccountPayable                        51000000.0    210000000.0
# ChangeInPrepaidAssets                        559000000.0    162000000.0
# ChangeInReceivables                        -2399000000.0    231000000.0
# ChangesInAccountReceivables                -2399000000.0    231000000.0
# OtherNonCashItems                            411000000.0   1982000000.0
# StockBasedCompensation                     14027000000.0  11992000000.0
# UnrealizedGainLossOnInvestmentSecurities             NaN    463000000.0
# AssetImpairmentCharge                       2432000000.0   2218000000.0
# DeferredTax                                  131000000.0  -3286000000.0
# DeferredIncomeTax                            131000000.0  -3286000000.0
# DepreciationAmortizationDepletion          11178000000.0   8686000000.0
# DepreciationAndAmortization                11178000000.0   8686000000.0
# NetIncomeFromContinuingOperations          39098000000.0  23200000000.0
#
#                                               2021-12-31     2020-12-31
# FreeCashFlow                               38993000000.0  23584000000.0
# RepurchaseOfCapitalStock                  -44537000000.0  -6272000000.0
# RepaymentOfDebt                             -677000000.0   -604000000.0
# IssuanceOfDebt                                       0.0            0.0
# CapitalExpenditure                        -18690000000.0 -15163000000.0
# InterestPaidSupplementalData                         0.0            NaN
# IncomeTaxPaidSupplementalData               8525000000.0   4229000000.0
# EndCashPosition                            16865000000.0  17954000000.0
# BeginningCashPosition                      17954000000.0  19279000000.0
# EffectOfExchangeRateChanges                 -474000000.0    279000000.0
# ChangesInCash                               -615000000.0  -1604000000.0
# FinancingCashFlow                         -50728000000.0 -10292000000.0
# CashFlowFromContinuingFinancingActivities -50728000000.0 -10292000000.0
# NetOtherFinancingCharges                   -5514000000.0  -3416000000.0
# NetCommonStockIssuance                    -44537000000.0  -6272000000.0
# CommonStockPayments                       -44537000000.0  -6272000000.0
# NetIssuancePaymentsOfDebt                   -677000000.0   -604000000.0
# NetShortTermDebtIssuance                      14000000.0     24000000.0
# NetLongTermDebtIssuance                     -677000000.0   -604000000.0
# LongTermDebtPayments                        -677000000.0   -604000000.0
# LongTermDebtIssuance                                 0.0            0.0
# InvestingCashFlow                          -7570000000.0 -30059000000.0
# CashFlowFromContinuingInvestingActivities  -7570000000.0 -30059000000.0
# NetOtherInvestingChanges                    -331000000.0    -36000000.0
# NetInvestmentPurchaseAndSale               12179000000.0 -14520000000.0
# SaleOfInvestment                           42586000000.0  25771000000.0
# PurchaseOfInvestment                      -30407000000.0 -40291000000.0
# NetBusinessPurchaseAndSale                  -851000000.0   -388000000.0
# PurchaseOfBusiness                          -851000000.0   -388000000.0
# NetPPEPurchaseAndSale                     -18567000000.0 -15115000000.0
# SaleOfPPE                                    123000000.0     48000000.0
# PurchaseOfPPE                             -18690000000.0 -15163000000.0
# OperatingCashFlow                          57683000000.0  38747000000.0
# CashFlowFromContinuingOperatingActivities  57683000000.0  38747000000.0
# ChangeInWorkingCapital                       700000000.0  -2723000000.0
# ChangeInOtherWorkingCapital                  187000000.0    108000000.0
# ChangeInOtherCurrentLiabilities              941000000.0   -527000000.0
# ChangeInOtherCurrentAssets                  -349000000.0    -34000000.0
# ChangeInPayablesAndAccruedExpense           4968000000.0   -785000000.0
# ChangeInAccruedExpense                      3544000000.0   -946000000.0
# ChangeInPayable                             1424000000.0    161000000.0
# ChangeInAccountPayable                      1436000000.0    -17000000.0
# ChangeInPrepaidAssets                      -1750000000.0    135000000.0
# ChangeInReceivables                        -3110000000.0  -1512000000.0
# ChangesInAccountReceivables                -3110000000.0  -1512000000.0
# OtherNonCashItems                           -127000000.0     85000000.0
# StockBasedCompensation                      9164000000.0   6536000000.0
# UnrealizedGainLossOnInvestmentSecurities    -232000000.0     33000000.0
# AssetImpairmentCharge                                0.0            0.0
# DeferredTax                                  609000000.0  -1192000000.0
# DeferredIncomeTax                            609000000.0  -1192000000.0
# DepreciationAmortizationDepletion           7967000000.0   6862000000.0
# DepreciationAndAmortization                 7967000000.0   6862000000.0
# NetIncomeFromContinuingOperations          39370000000.0  29146000000.0
